# %%
# reference：https://github.com/thushv89/udacity_deeplearning_complete/blob/master/5_word2vec_CBOW.ipynb
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile 
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
    # skip window is the amount of words we're looking at from each side of a given word
    # creates a single batch
    global data_index

    span = 2 * skip_window + 1 # [ skip_window target skip_window ]

    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # e.g if skip_window = 2 then span = 5
    # span is the length of the whole frame we are considering for a single word (left + word + right)
    # skip_window is the length of one side

    # queue which add and pop at the end
    buffer = collections.deque(maxlen=span)

    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    # num_skips => # of times we select a random word within the span?
    # batch_size (8) and num_skips (2) (4 times)
    # batch_size (8) and num_skips (1) (8 times)
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        target_to_avoid = [ skip_window ] # we only need to know the words around a given word, not the word itself

        # do this num_skips (2 times)
        # do this (1 time)

        # add selected target to avoid_list for next time
        col_idx = 0
        for j in range(span):
            if j==span//2:
                continue
            # e.g. i=0, j=0 => 0; i=0,j=1 => 1; i=1,j=0 => 2
            batch[i,col_idx] = buffer[j] # [skip_window] => middle element
            col_idx += 1
        labels[i, 0] = buffer[target]

        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels



for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    
    print('    batch:', [[reverse_dictionary[bii] for bii in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
#使用ski-gram来训练

num_steps = 100001
#第一步定义输入输出，其他张量和参数
if __name__ == '__main__':
    batch_size = 128
    embedding_size = 128 # Dimension of the embedding vector.
    skip_window = 1 # How many words to consider left and right.
    num_skips = 2 # How many times to reuse an input to generate a label.
   
    # We pick a random validation set to sample nearest neighbors. here we limit the
    # validation samples to the words that have a low numeric ID, which by
    # construction are also the most frequent.
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100 # Only pick dev samples in the head of the distribution.
    # pick 16 samples from 100
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples,random.sample(range(1000,1000+valid_window), valid_size//2))
    num_sampled = 64 # Number of negative examples to sample.

    graph = tf.Graph()

    with graph.as_default(), tf.device('/cpu:0'):

        # Input data.
        train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*skip_window])
        train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
        valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

        # Variables.
        # embedding, vector for each word in the vocabulary
        embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
        softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Averaging embeddings accross the full context into a single embedding layer
        context_embeddings = []
        for i in range(2*skip_window):
            context_embeddings.append(tf.nn.embedding_lookup(embeddings, train_dataset[:,i]))
            #使用embedding_lookup 来查找每个输入的对应embedding
        avg_embed =  tf.reduce_mean(tf.stack(axis=0,values=context_embeddings),0,keep_dims=False)

        # Compute the softmax loss, using a sample of the negative labels each time.
        # inputs are embeddings of the train words
        # with this loss we optimize weights, biases, embeddings

        #采用部分取样来计算
        loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

        # Optimizer.
        optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

        # Compute the similarity between minibatch examples and all embeddings.
        # We use the cosine distance:
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
        similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

    with tf.Session(graph=graph) as session:
        tf.global_variables_initializer().run()
        print('Initialized')
        average_loss = 0
        for step in range(num_steps):
            batch_data, batch_labels = generate_batch(batch_size, skip_window)
            feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
            _, l = session.run([optimizer, loss], feed_dict=feed_dict)
            average_loss += l
            if step % 2000 == 0:
                if step > 0:
                    average_loss = average_loss / 2000
                    # The average loss is an estimate of the loss over the last 2000 batches.
                print('Average loss at step %d: %f' % (step, average_loss))
                average_loss = 0
            # note that this is expensive (~20% slowdown if computed every 500 steps)
            if step % 10000 == 0:
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = reverse_dictionary[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = reverse_dictionary[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
        final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-6-3160d5537020>:39: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From <ipython-input-6-3160d5537020>:53: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Initialized
# Average loss at step 0: 7.096576
# Nearest to he: mechanically, castle, plurality, capsule, fugitive, polystyrene, gigahertz, maya,
# Nearest to these: duchess, pulling, camillo, gage, activates, sabers, luba, mixed,
# Nearest to s: mind, hero, microkernel, demoralized, zionists, reconstructed, lal, midsummer,
# Nearest to about: overkill, pinscher, optimistic, ras, oberon, pnh, ugaritic, woo,
# Nearest to from: pont, vacated, antelope, maze, dues, permissible, emulated, rocked,
# Nearest to would: bindings, characterizes, cardini, proletarians, mononoke, martini, conclusively, moderne,
# Nearest to b: weekends, booting, starfish, belladonna, beyond, coasts, delete, lil,
# Nearest to i: software, show, maga, scientology, megatokyo, fight, tanning, rivers,
# Nearest to existence: finalised, instruments, kat, maul, mango, guppy, mulberry, reconquered,
# Nearest to grand: figure, reinhold, pastiche, discreetly, sodomy, conference, dinara, overdose,
# Nearest to bbc: moravian, offshoot, chlorine, fasttrack, microkernels, clipperton, milne, voronin,
# Nearest to accepted: tabloids, gpcrs, ioannis, hagiography, deployed, gavrilo, hardness, drawings,
# Nearest to brother: mat, utmost, satirists, coeducational, levine, cameroon, inquart, clinched,
# Nearest to discovered: agitated, controls, slate, dict, ionosphere, emanuel, gin, fledgling,
# Nearest to scale: melinda, jens, gentle, gardener, meditation, premieres, stuarts, wrist,
# Nearest to arts: volatility, sufferers, bushmen, adf, choose, goss, gigabytes, dispelling,
# Average loss at step 2000: 4.042619
# Average loss at step 4000: 3.506941
# Average loss at step 6000: 3.341928
# Average loss at step 8000: 3.196517
# Average loss at step 10000: 3.150409
# Nearest to he: she, it, who, they, prediction, depleted, reflecting, canadiens,
# Nearest to these: some, many, vesta, mixed, paulist, their, which, social,
# Nearest to s: wink, his, demoralized, zionists, foothills, ion, titian, hero,
# Nearest to about: pinscher, cling, losers, lubricants, ras, subsidiaries, daytona, overkill,
# Nearest to from: under, in, on, pont, slaps, antelope, circulating, hominidae,
# Nearest to would: can, will, could, might, may, should, seamus, fearsome,
# Nearest to b: d, booting, vehement, betty, abt, graffiti, conlang, lil,
# Nearest to i: rivers, salty, software, recitation, wpa, ii, parthian, interdiction,
# Nearest to existence: mango, kat, guppy, instruments, maul, klaip, finalised, rajons,
# Nearest to grand: discreetly, overdose, reinhold, figure, sodomy, dinara, trill, conference,
# Nearest to bbc: moravian, chlorine, fasttrack, quadruple, microkernels, offshoot, melts, erie,
# Nearest to accepted: tabloids, ioannis, animate, hagiography, bundeswehr, muluzi, backbench, retires,
# Nearest to brother: utmost, satirists, clinched, father, cameroon, melancholia, stoney, balochistan,
# Nearest to discovered: dict, fledgling, controls, bangor, manfred, emanuel, cumbria, megalithic,
# Nearest to scale: melinda, jens, gentle, meditation, gardener, irn, premieres, steiner,
# Nearest to arts: volatility, control, sufferers, bushmen, adf, dispelling, rcn, goss,
# Average loss at step 12000: 3.174037
# Average loss at step 14000: 3.127492
# Average loss at step 16000: 3.151042
# Average loss at step 18000: 3.103609
# Average loss at step 20000: 2.991650
# Nearest to he: she, it, they, who, there, reflecting, prediction, canadiens,
# Nearest to these: some, many, such, mixed, they, which, peculiarity, living,
# Nearest to s: his, demoralized, wink, zionists, rosa, foothills, upsets, our,
# Nearest to about: pinscher, lubricants, cling, losers, within, clinton, overkill, daytona,
# Nearest to from: under, into, upon, pont, maximum, pipeline, meetings, antelope,
# Nearest to would: can, will, could, might, may, should, must, does,
# Nearest to b: d, booting, lil, vehement, nasrallah, delete, riflemen, chlorus,
# Nearest to i: you, we, rivers, salty, ii, they, recitation, naur,
# Nearest to existence: mango, guppy, kat, klaip, instruments, maul, rajons, ralston,
# Nearest to grand: suppressor, sodomy, overdose, discreetly, trill, dinara, fiesta, satirically,
# Nearest to bbc: moravian, melts, quadruple, chlorine, microkernels, offshoot, fasttrack, mammals,
# Nearest to accepted: tabloids, animate, backbench, ioannis, emptive, drawings, bundeswehr, muluzi,
# Nearest to brother: father, utmost, clinched, satirists, cameroon, stoney, hogan, melancholia,
# Nearest to discovered: dict, bangor, fledgling, controls, manfred, emanuel, cumbria, megalithic,
# Nearest to scale: melinda, jens, gentle, irn, harps, steiner, meditation, premieres,
# Nearest to arts: volatility, control, sufferers, citations, dispelling, goss, adf, bushmen,
# Average loss at step 22000: 3.053628
# Average loss at step 24000: 3.025599
# Average loss at step 26000: 2.984062
# Average loss at step 28000: 3.015334
# Average loss at step 30000: 2.992606
# Nearest to he: she, it, they, who, there, originally, later, prediction,
# Nearest to these: some, such, many, mixed, several, both, they, guam,
# Nearest to s: fabian, jr, evasive, demoralized, technicians, ion, wink, titian,
# Nearest to about: clinton, pinscher, lubricants, regarding, cling, losers, around, daytona,
# Nearest to from: under, into, cantonal, circulating, pont, maximum, antelope, upon,
# Nearest to would: will, can, could, might, may, should, must, cannot,
# Nearest to b: d, delete, riflemen, booting, coasts, maintainer, nasrallah, adder,
# Nearest to i: you, we, ii, rivers, salty, they, recitation, t,
# Nearest to existence: mango, guppy, klaip, kat, maul, instruments, rajons, ralston,
# Nearest to grand: suppressor, fiesta, satirically, overdose, trending, discreetly, trill, reinhold,
# Nearest to bbc: moravian, fasttrack, metastability, mammals, quadruple, melts, committee, milne,
# Nearest to accepted: tabloids, animate, backbench, emptive, ioannis, bundeswehr, muluzi, drawings,
# Nearest to brother: father, clinched, stoney, satirists, utmost, citric, crazed, medway,
# Nearest to discovered: dict, bangor, controls, fledgling, manfred, cumbria, emanuel, megalithic,
# Nearest to scale: jens, melinda, harps, irn, gentle, steiner, professional, grohl,
# Nearest to arts: volatility, control, sufferers, dispelling, citations, adf, bushmen, goss,
# Average loss at step 32000: 2.843257
# Average loss at step 34000: 2.948941
# Average loss at step 36000: 2.933978
# Average loss at step 38000: 2.941173
# Average loss at step 40000: 2.922665
# Nearest to he: she, it, they, there, who, prediction, later, probably,
# Nearest to these: such, some, many, several, those, both, which, they,
# Nearest to s: zionists, evasive, jr, technicians, purporting, demoralized, his, aichi,
# Nearest to about: around, regarding, clinton, pinscher, lubricants, cling, losers, daytona,
# Nearest to from: into, under, maximum, upon, during, pipeline, across, through,
# Nearest to would: will, can, could, may, might, must, should, cannot,
# Nearest to b: d, nasrallah, riflemen, c, te, booting, delete, adder,
# Nearest to i: we, you, ii, they, rivers, alicante, comrades, t,
# Nearest to existence: mango, guppy, klaip, kat, instruments, maul, ralston, rajons,
# Nearest to grand: suppressor, overdose, satirically, fiesta, trending, discreetly, reinhold, conference,
# Nearest to bbc: moravian, metastability, fasttrack, quadruple, milne, committee, mammals, stockholders,
# Nearest to accepted: animate, tabloids, backbench, depicted, emptive, sailed, ioannis, muluzi,
# Nearest to brother: father, clinched, son, stoney, satirists, citric, utmost, asbury,
# Nearest to discovered: stated, bangor, confirmed, controls, dict, fledgling, manfred, cumbria,
# Nearest to scale: jens, harps, melinda, steiner, irn, gentle, eocene, grohl,
# Nearest to arts: volatility, control, dispelling, ammanati, citations, sufferers, adf, bushmen,
# Average loss at step 42000: 2.940067
# Average loss at step 44000: 2.942768
# Average loss at step 46000: 2.905600
# Average loss at step 48000: 2.861766
# Average loss at step 50000: 2.849748
# Nearest to he: she, it, they, there, who, originally, probably, soon,
# Nearest to these: many, some, several, such, those, various, both, they,
# Nearest to s: his, disclaimer, technicians, demoralized, zionists, aichi, fabian, purporting,
# Nearest to about: regarding, clinton, cling, around, pinscher, lubricants, asked, daytona,
# Nearest to from: during, into, maximum, pont, across, under, in, circulating,
# Nearest to would: will, can, could, may, might, should, must, cannot,
# Nearest to b: d, vehement, w, riflemen, turbo, booting, c, adder,
# Nearest to i: we, ii, you, rivers, comrades, t, recitation, they,
# Nearest to existence: mango, guppy, klaip, kat, ralston, maul, gallico, rajons,
# Nearest to grand: satirically, conference, overdose, fiesta, suppressor, trending, schwitters, trill,
# Nearest to bbc: moravian, metastability, quadruple, committee, fasttrack, mammals, grady, pooh,
# Nearest to accepted: backbench, depicted, animate, tabloids, sailed, known, criticized, defined,
# Nearest to brother: father, son, clinched, utmost, citric, asbury, stoney, satirists,
# Nearest to discovered: stated, confirmed, held, bangor, followed, found, dict, manfred,
# Nearest to scale: jens, harps, melinda, steiner, eocene, irn, gentle, din,
# Nearest to arts: control, volatility, ammanati, dispelling, citations, sufferers, dinah, sena,
# Average loss at step 52000: 2.888335
# Average loss at step 54000: 2.864508
# Average loss at step 56000: 2.862066
# Average loss at step 58000: 2.763226
# Average loss at step 60000: 2.826608
# Nearest to he: she, it, they, who, there, soon, originally, eventually,
# Nearest to these: several, such, some, many, those, various, they, both,
# Nearest to s: demoralized, his, cpm, disclaimer, xi, aichi, dries, jr,
# Nearest to about: regarding, asked, cling, around, clinton, defiance, lubricants, concealing,
# Nearest to from: during, through, into, under, across, maximum, circulating, necklaces,
# Nearest to would: will, can, could, might, may, should, must, cannot,
# Nearest to b: d, z, riflemen, c, guybrush, turbo, w, gendarmerie,
# Nearest to i: we, you, ii, comrades, they, rivers, macron, devise,
# Nearest to existence: mango, klaip, guppy, ralston, kat, maul, messiah, instruments,
# Nearest to grand: satirically, suppressor, conference, overdose, fiesta, trending, trill, schwitters,
# Nearest to bbc: moravian, metastability, committee, quadruple, stockholders, fasttrack, whyte, pooh,
# Nearest to accepted: depicted, criticized, backbench, animate, known, defined, tabloids, sailed,
# Nearest to brother: father, son, wife, clinched, utmost, uncle, citric, asbury,
# Nearest to discovered: stated, confirmed, followed, found, bangor, decided, held, dispatched,
# Nearest to scale: harps, jens, melinda, steiner, randall, eocene, irn, gentle,
# Nearest to arts: control, ammanati, dispelling, volatility, citations, sena, sufferers, guerrilla,
# Average loss at step 62000: 2.835956
# Average loss at step 64000: 2.777734
# Average loss at step 66000: 2.771411
# Average loss at step 68000: 2.720560
# Average loss at step 70000: 2.777060
# Nearest to he: she, it, they, who, there, originally, soon, eventually,
# Nearest to these: several, some, those, many, such, they, both, various,
# Nearest to s: demoralized, his, jr, zionists, whose, thine, titian, fabian,
# Nearest to about: regarding, cling, asked, concealing, clinton, defiance, lubricants, around,
# Nearest to from: maximum, under, through, into, necklaces, towards, during, across,
# Nearest to would: will, could, can, might, should, may, must, cannot,
# Nearest to b: d, guybrush, commercialize, vehement, lysine, turbo, melaka, riflemen,
# Nearest to i: we, you, ii, lays, comrades, they, rivers, devise,
# Nearest to existence: mango, klaip, guppy, kat, ralston, gallico, origin, maul,
# Nearest to grand: satirically, goguryeo, conference, fiesta, crafty, schwitters, suppressor, seduce,
# Nearest to bbc: moravian, metastability, committee, erie, stockholders, exile, pooh, whyte,
# Nearest to accepted: criticized, depicted, defined, known, backbench, animate, ratified, sailed,
# Nearest to brother: father, son, wife, uncle, utmost, life, clinched, mother,
# Nearest to discovered: stated, confirmed, followed, found, held, bangor, decided, dispatched,
# Nearest to scale: harps, melinda, jens, steiner, eocene, narrative, randall, irn,
# Nearest to arts: ammanati, citations, control, volatility, dispelling, sena, sufferers, diuretics,
# Average loss at step 72000: 2.802215
# Average loss at step 74000: 2.658245
# Average loss at step 76000: 2.801212
# Average loss at step 78000: 2.821321
# Average loss at step 80000: 2.783304
# Nearest to he: she, it, they, who, there, we, originally, soon,
# Nearest to these: several, some, such, those, many, they, which, various,
# Nearest to s: aroma, whose, technicians, demoralized, isbn, beaconsfield, my, gov,
# Nearest to about: regarding, cling, around, concealing, asked, concerning, defiance, lubricants,
# Nearest to from: through, during, across, into, circulating, obedient, under, pont,
# Nearest to would: will, could, can, might, should, may, must, cannot,
# Nearest to b: d, commercialize, riflemen, z, guybrush, abb, turbo, c,
# Nearest to i: you, we, ii, they, lays, t, anything, salty,
# Nearest to existence: klaip, mango, origin, guppy, messiah, maul, kat, status,
# Nearest to grand: goguryeo, conference, satirically, fiesta, crafty, suppressor, overdose, trending,
# Nearest to bbc: moravian, erie, stockholders, metastability, committee, whyte, pooh, quadruple,
# Nearest to accepted: criticized, depicted, known, defined, ratified, backbench, sailed, animate,
# Nearest to brother: father, son, wife, life, uncle, clinched, utmost, mother,
# Nearest to discovered: stated, confirmed, followed, found, decided, held, released, announced,
# Nearest to scale: harps, atmospheres, eocene, narrative, steiner, melinda, jens, randall,
# Nearest to arts: ammanati, citations, sena, dispelling, control, volatility, guerrilla, dinah,
# Average loss at step 82000: 2.674377
# Average loss at step 84000: 2.773732
# Average loss at step 86000: 2.742671
# Average loss at step 88000: 2.760999
# Average loss at step 90000: 2.742254
# Nearest to he: she, it, they, there, who, we, originally, eventually,
# Nearest to these: several, such, some, those, many, they, various, which,
# Nearest to s: demoralized, isbn, technicians, his, disclaimer, titian, upsets, saves,
# Nearest to about: regarding, around, asked, cling, daytona, concerning, encyclopedists, lubricants,
# Nearest to from: across, into, through, during, obedient, in, pipeline, under,
# Nearest to would: will, could, might, can, should, may, must, cannot,
# Nearest to b: d, z, guybrush, commercialize, riflemen, c, abb, r,
# Nearest to i: you, we, ii, they, lays, iii, macron, t,
# Nearest to existence: klaip, mango, status, guppy, maul, messiah, kat, origin,
# Nearest to grand: goguryeo, satirically, fiesta, conference, trending, crafty, suppressor, schwitters,
# Nearest to bbc: erie, moravian, stockholders, whyte, pooh, uk, grady, metastability,
# Nearest to accepted: criticized, depicted, defined, provided, ratified, supported, backbench, known,
# Nearest to brother: father, son, wife, uncle, daughter, mother, life, alkaloids,
# Nearest to discovered: stated, followed, confirmed, found, decided, created, released, announced,
# Nearest to scale: harps, atmospheres, eocene, steiner, narrative, edelman, melinda, randall,
# Nearest to arts: citations, ammanati, sena, dispelling, guerrilla, dinah, volatility, buildings,
# Average loss at step 92000: 2.692341
# Average loss at step 94000: 2.727806
# Average loss at step 96000: 2.709671
# Average loss at step 98000: 2.385630
# Average loss at step 100000: 2.426692
# Nearest to he: she, it, they, there, we, who, even, briefly,
# Nearest to these: such, several, those, some, many, various, certain, they,
# Nearest to s: demoralized, my, whose, american, isbn, jr, foothills, his,
# Nearest to about: regarding, around, asked, concealing, cling, lubricants, kk, daytona,
# Nearest to from: across, through, into, during, benzoic, cantonal, chasm, towards,
# Nearest to would: will, could, might, can, should, may, must, cannot,
# Nearest to b: d, abb, pomona, lysine, eugen, gendarmerie, vehement, guybrush,
# Nearest to i: you, we, ii, lays, they, macron, glittering, iii,
# Nearest to existence: klaip, status, mango, origin, participation, obligation, rest, messiah,
# Nearest to grand: goguryeo, conference, satirically, fiesta, crafty, trending, suppressor, discreetly,
# Nearest to bbc: erie, whyte, pooh, stockholders, moravian, committee, ferrol, uk,
# Nearest to accepted: criticized, ratified, defined, depicted, provided, supported, recognized, backbench,
# Nearest to brother: father, son, wife, uncle, daughter, mother, life, alkaloids,
# Nearest to discovered: stated, followed, confirmed, created, found, released, announced, decided,
# Nearest to scale: atmospheres, eocene, harps, steiner, randall, edelman, baldrick, narrative,
# Nearest to arts: citations, ammanati, sena, dispelling, buildings, dinah, scaffold, guerrilla,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
